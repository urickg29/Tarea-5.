# %%
# !cat junio.dat
# Out:
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, año de ingreso
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
# 5754,ANGEL,GOMEZ,GARRIDO,1,9850,2020
# 5345,JESUS,MARTIN,SANTOS,2,9850,2016
# 3267,DAVID,JIMENEZ,LOZANO,2,9850,2017
# 8765,PEDRO,RUIZ,GUERRERO,2,9850,2017
# 5454,DANIEL,HERNANDEZ,CANO,3,9850,2018
# 3456,ALEJANDRO,DIAZ,PRIETO,2,9850,2018
# 3445,MARIA,MORENO,MENDEZ,1,9850,2018
# 9088,ALBERTO,MU�OZ,CRUZ,1,9850,2017
# 8877,RAFAEL,ALVAREZ,FLORES,2,9850,2017
# 6767,FERNANDO,ROMERO,HERRERA,4,9850,2019
# 5654,PABLO,ALONSO,GALLEGO,1,9850,2019
# 4323,JORGE,GUTIERREZ,MARQUEZ,2,9850,2020
# 2232,RAMON,NAVARRO,LEON,1,9850,2016

# %%
archivo = open('junio.dat','rt', encoding= 'latin-1')
print( archivo.read() )
# Out:
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, aÃ±o de ingreso
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
# 5754,ANGEL,GOMEZ,GARRIDO,1,9850,2020
# 5345,JESUS,MARTIN,SANTOS,2,9850,2016
# 3267,DAVID,JIMENEZ,LOZANO,2,9850,2017
# 8765,PEDRO,RUIZ,GUERRERO,2,9850,2017
# 5454,DANIEL,HERNANDEZ,CANO,3,9850,2018
# 3456,ALEJANDRO,DIAZ,PRIETO,2,9850,2018
# 3445,MARIA,MORENO,MENDEZ,1,9850,2018
# 9088,ALBERTO,MUOZ,CRUZ,1,9850,2017
# 8877,RAFAEL,ALVAREZ,FLORES,2,9850,2017
# 6767,FERNANDO,ROMERO,HERRERA,4,9850,2019
# 5654,PABLO,ALONSO,GALLEGO,1,9850,2019
# 4323,JORGE,GUTIERREZ,MARQUEZ,2,9850,2020
# 2232,RAMON,NAVARRO,LEON,1,9850,2016

# %%
class Trabajador:
  def __init__( self, nt, nom, pat, mat, he, sb, ai ):
    self.__numero_trabajador = nt
    self.__nombres = nom
    self.__paterno = pat
    self.__materno = mat
    self.__horas_extra = he
    self.__sueldo_base = sb
    self.__anio_ingreso = ai

  #aqui van todos los metodos de acceso

  def set_nt( self , nt):
    self.__numero_trabajador

  def get_nt( self ):
    return self.__numero_trabajador

  def set_nom( self, nom):
    self.__nombres

  def get_nom(self):
    return self.__nombres

  def set_pat( self, pat):
    self.__paterno
  
  def get_pat( self ):
    return self.__paterno

  def set_mat( self, mat):
    self.__materno

  def get_mat( self ):
    return self.__materno

  def set_he( self, he ):
    self.__horas_extra

  def get_he( self ):
    return self.__horas_extra

  def set_sb( self, sb):
    self.__sueldo_base

  def get_sb( self ):
    return self.__sueldo_base

  def set_ai( self, ai):
    self.__anio_ingreso

  def get_ai( self ):
    return self.__anio_ingreso
  
    #metodos de uso grl. --> metodos que hacen calculos de la logica

  def mostrar_sueldos( self, sb):
    print(__sueldo_base)

# %%
class Nomina:
  def __init__( self):
    # leer el archivo
    archivo = open('junio.dat','rt', encoding= 'latin-1')
    info = archivo

    for index in range( len(info) ):
      info[ index ] = info[ index ].rstrip( '\n' ).split( ',' )
      print(info[index])

    
    self.empleados = Array(15)
    # creacion de objetos por cada linea leida y almacenada en el array.

    print("Lista de trabajadores: ")

    trabajadores = Array(15)


    trabajadores.set_item(1 , 2345)
    trabajadores.set_item(2 , 5754)
    trabajadores.set_item(3 , 5345)
    trabajadores.set_item(4 , 3267)
    trabajadores.set_item(5 , 8765)
    trabajadores.set_item(6 , 5454)
    trabajadores.set_item(7 , 3456)
    trabajadores.set_item(8 , 3445)
    trabajadores.set_item(9 , 9088)
    trabajadores.set_item(10 , 8877)
    trabajadores.set_item(11 , 6767)
    trabajadores.set_item(12 , 5654)
    trabajadores.set_item(13 , 4323)
    trabajadores.set_item(14 , 2232)



    num_busc = int (input("¿Que trabajador busca?"))
    enlist = False

    for conta in range( trabajadores.get_Length()):
      if num_busc == trabajadores.get_item( conta ):
        print("                                     ", info[0])
        print("El trabajador es este: ", info[conta])
        enlist = True
        break

    if enlist:
      print("El Trabajador esta en la lista")
    else:
      print("El Trabajador no esta en la lista")

    


  def calcular_sueldos( self ):
    #iterar sobre el Array y hacer el calculo de sueldos
    
    print("Sueldos")
    res = 0

    for betra in informacion[1:]:
      num = int(betra[5])
 
      res = num + res
 
    final = res/14
    print(final)


  def encontrar_mayor_ant( self ):
    # Parte para encontrar el de mayor anitiguedad y el de menor anitguedad en el puesto
    menosantiguo = 1

    for betra in informacion[1:]:
    
      anio = int(betra[6])
      antiguedad = 2021 - anio

      if antiguedad > masantiguo:
        masantiguo = antiguedad
    
      if antiguedad < menosantiguo:
        menosantiguo = antiguedad

    print(f"El trabajador mas antiguo es de {masantiguo} años")
    print(f"El trabajador con menor antiguedad es de {menosantiguo} años")
